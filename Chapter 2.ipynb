# %% [markdown]
# # Basic Commands

# %%
x <- c(1,2,3,4)

# %%
x
# Out:
# [1] 1 2 3 4

# %%
length(x)
# Out:
# [1] 4

# %%
ls() #List of objects we have created
# Out:
# [1] "x"

# %%
rm(x) #Remove a specific object

# %%
ls()
# Out:
# character(0)

# %%
rm(list=ls()) #Removes all created Objects

# %%
x= matrix(c(1,2,3,4),2,2,TRUE) #Another way of declaring a matrix

# %%
x
# Out:
#      [,1] [,2]
# [1,] 1    2
# [2,] 3    4

# %%
y =rnorm(5) #Creates standard normal random variables with mean=0,sd=1

# %%
y
# Out:
# [1] -1.212476 -1.429567  1.577319  0.944330  1.509095

# %%
z= y+rnorm(5,mean = 50, sd = 0.1)

# %%
z
# Out:
# [1] 48.78536 48.47807 51.53233 50.99782 51.59394

# %%
cor(y,z) #Computes correlation between specified arguments
# Out:
# [1] 0.9992506

# %%
set.seed(1301)#To produce same outputs with rnorm

# %% [markdown]
# # Graphics

# %%
x=rnorm(10)
y=rnorm(10)
plot(x,y,xlab="This is the X-Axis",ylab="This is the Y-Axis", main="Plot of Y versus X")
# Out:
# Plot with title "Plot of Y versus X"

# %%
pdf("Figure.pdf")#To create a pdf

# %%
plot(x,y,col="green")
# Out:
# plot without title

# %%
dev.off()#We are done creating the plot
# Out:
# pdf
#   3

# %%
x=1:10
y=x
f=outer(x,y,function(x,y)cos(y)/(1+x^2))
contour(x,y,f)
# Out:
# plot without title

# %%
plot.new()
contour(x,y,f,nlevels=45,add=T)
# Out:
# plot without title

# %%
fa=(f-t(f))/2

# %%
contour(x,y,fa,nlevels=15)
# Out:
# plot without title

# %%
image(x,y,fa)
# Out:
# plot without title

# %%
persp(x,y,fa)
# Out:
# plot without title

# %%
persp(x,y,fa,theta = 30)
# Out:
# plot without title

# %%
persp(x,y,fa,theta = 30,phi=20)
# Out:
# plot without title

# %%
persp(x,y,fa,theta = 30,phi = 70)
# Out:
# plot without title

# %%
persp(x,y,fa,theta = 30, phi = 40)
# Out:
# plot without title

# %%
# Out:
# Warning message in file(file, "rt"):
# "cannot open file 'Auto.data': No such file or directory"
# Error in file(file, "rt"): cannot open the connection
# Traceback:
#
# 1. read.table("Auto.data")
# 2. file(file, "rt")
